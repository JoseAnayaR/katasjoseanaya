# %% [markdown]
# #Ejercicio 1

# %%
new_planet = ''
planets = []
while new_planet.lower() != 'done':
    if new_planet:
        planets.append(new_planet)
    new_planet = input('Enter new planet or done for done')

# %% [markdown]
# #Ejercicio 2

# %%
for planet in planets:
    print(planet)
# Out:
# marte
# tierra
# jupiter
# urano
