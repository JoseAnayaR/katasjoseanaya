# %%
asteroide_1 = 49
if velocidad_del_asteroide > 25:
    print ("Advertencia de impacto de asteroide")
# Out:
# Advertencia de impacto de asteroide

# %%
asteroide_2 = 19
if asteroide_2 > 20:
    print('¡Busca un asteroide en el cielo!')
elif asteroide_2 == 20:
    print('¡Busca un asteroide en el cielo!')
else:
    print('No hay asteroides cerca')
# Out:
# No hay asteroides cerca

# %%
velocidad_del_asteroide = input('Ingrese velocidad de asteroide:')
tamaño_de_asteroide = input('Ingrese tamaño del asteroide:')
if velocidad_del_asteroide>= str(25) or tamaño_de_asteroide >= str(25):
    print('Peligro de impacto')
elif velocidad_del_asteroide>= str(20) and tamaño_de_asteroide <=str(25):
    print('Busca un asteroide en el cielo')
else: 
    print('No hay nignun asteroide cerca')
# Out:
# No hay nignun asteroide cerca
