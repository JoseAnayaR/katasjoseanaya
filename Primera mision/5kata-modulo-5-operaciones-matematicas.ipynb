# %% [markdown]
# #Ejercicio 1

# %%
earth = 149597870
jupyter = 778547200
earthtojupyter = earth - jupyter
miles=earthtojupyter*.621
print(abs(earthtojupyter))
print(abs(floor(miles)))
# Out:
# 628949330
# 390577534

# %% [markdown]
# #Ejercicio 2

# %%
planet_1 = input("Introduzca distancia del planeta 1")
planet_2 = input("Introduzca distancia del planeta 2")
planet_1 = int(planet_1)
planet_2 = int(planet_2)
distance = abs(planet_1-planet_2)
distance_miles = abs(distance*.621)
print(distance)
print(distance_miles)
# Out:
# 50300000
# 31236300.0

# %%
# Out:
# 5
