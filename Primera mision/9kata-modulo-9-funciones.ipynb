# %% [markdown]
# #Ejercicio 1

# %%
def reporte_combustible(tanque_1, tanque_2, tanque_3):
    total_average = (tanque_1 + tanque_2 + tanque_3) / 3
    return f"""Reporte de combustible:
    Promedio: {average([tanque_1, tanque_2, tanque_3])}
    Tanque 1: {tanque_1}
    Tanque 2: {tanque_2}
    Tanque 3: {tanque_3} 
    """

# %%
print(reporte_combustible(300, 300, 300))
# Out:
# Reporte de combustible:
#     Promedio: 300.0
#     Tanque 1: 300
#     Tanque 2: 300
#     Tanque 3: 300

# %%
 def average(values):
    total = sum(values)
    numero_de_tanques = len(values)
    return total / numero_de_tanques
average([100, 100, 100])
# Out:
# 100.0

# %% [markdown]
# #Ejercicio 2

# %%
def mission_report(pre_launch_time, flight_time, destination, external_tank, main_tank):
    return f"""
    Mission to {destination}
    Total travel time: {pre_launch_time + flight_time} minutes
    Total fuel left: {external_tank + main_tank} gallons
    """

print(mission_report(14, 51, "Moon", 200000, 300000))
# Out:
#     Mission to Moon
#     Total travel time: 65 minutes
#     Total fuel left: 500000 gallons

# %%
def bitacora_de_mision(destination, *minutes, **fuel_reservoirs):
    return f"""
    Mission to {destination}
    Total travel time: {sum(minutes)} minutes
    Total fuel left: {sum(fuel_reservoirs.values())}
    """

print(bitacora_de_mision("Moon", 10, 15, 51, main=300000, external=200000))
# Out:
#     Mission to Moon
#     Total travel time: 76 minutes
#     Total fuel left: 500000

# %%
def bitacora(destination, *minutes, **fuel_reservoirs):
    main_report = f"""
    Mission to {destination}
    Total travel time: {sum(minutes)} minutes
    Total fuel left: {sum(fuel_reservoirs.values())}
    """
    for tank_name, gallons in fuel_reservoirs.items():
        main_report += f"{tank_name} tank --> {gallons} gallons left\n"
    return main_report

print(bitacora("Moon", 8, 11, 55, main=300000, external=200000))
# Out:
#     Mission to Moon
#     Total travel time: 74 minutes
#     Total fuel left: 500000
#     main tank --> 300000 gallons left
# external tank --> 200000 gallons left
