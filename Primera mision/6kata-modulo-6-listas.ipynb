# %% [markdown]
# #Ejercicio 1

# %%
planets = ['Mercurio', 'Venus', 'Tierra', 'Marte', 'Jupiter', 'Saturno', 'Urano', 'Neptuno']
print("El numero de planetas es", len(planets))
# Out:
# El numero de planetas es 8

# %%
planets.append('Pluton')
print("Ahora hay", numero_planetas, ', el ultimo agregado es ', planets[-1])
# Out:
# Ahora hay 9 , el ultimo agregado es  Pluton

# %% [markdown]
# #Ejercicio 2

# %%
usuario = input('Cual es tu planeta favorito')

# %%
user_index = planets.index(usuario)
print(usuario,'es el planeta numero', user_index + 1, 'desde el sol')
# Out:
# Tierra es el planeta numero 3 desde el sol

# %%
planetas_mas_cercanos = planets[0:user_index]
print(planetas_mas_cercanos, 'Estan mas cerca del sol que ', usuario)
# Out:
# ['Mercurio', 'Venus'] Estan mas cerca del sol que  Tierra

# %%
print(planets[user_index + 1:], 'Estan mas lejos del sol que ' + usuario)
# Out:
# ['Marte', 'Jupiter', 'Saturno', 'Urano', 'Neptuno', 'Pluton'] Estan mas lejos del sol que Tierra
